# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
from matplotlib.patches import PathPatch as Patch
import numpy as np
import pandas as pd
import time
import os
import seaborn as sns
from scipy import stats
import sklearn.preprocessing as skp
import sklearn.cluster as skc
from sklearn.mixture import GaussianMixture
from sklearn.cluster import KMeans
from sklearn.mixture import BayesianGaussianMixture
from sklearn.model_selection import train_test_split
from scipy import linalg
import itertools

# %%
from matplotlib.patches import Ellipse
color_iter = itertools.cycle(["navy", "c", "cornflowerblue", "gold", "darkorange","green","pink"])




def draw_ellipse(mean, covariance, alpha,color,ax=None):
    ax = plt.gca()
    v, w = linalg.eigh(covariance)
    v = 2.0 * np.sqrt(2.0) * np.sqrt(v)
    u = w[0] / linalg.norm(w[0])
        # as the DP will not use every component it has access to
        # unless it needs it, we shouldn't plot the redundant
        # components.
        #if not np.any(Y_ == i):
         #   continue
        #plt.scatter(X[Y_ == i, 0], X[Y_ == i, 1], 0.8, color=color)

    # Plot an ellipse to show the Gaussian component
    angle = np.arctan(u[1] / u[0])
    angle = 180.0 * angle / np.pi  # convert to degrees
    ell = Ellipse(mean, v[0], v[1], angle=180.0 + angle, color=color)
    #ell.set_clip_box(splot.bbox)
    ell.set_alpha(alpha)
    #ax.add_patch(ell)
    ax.add_artist(ell)

# %%
outdir = './data/processed_data'

# %%
 # read data from the file and plot 
filename = os.path.join(outdir, f"cleanded_diabetes_data.csv" )    
diabetes_df = pd.read_csv(filename)

# %%
# drop Diabetes_012 column from dataset to get input matrix X
X = diabetes_df.drop('Diabetes_012', axis=1)
# Extract Diabetes_012 column to generate output vector y
y = diabetes_df['Diabetes_012']

# %%
X_train, X_test, y_train_true, y_test_true = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# ## Decide on the cluster count using Elbow method

# %%
###Decide n-cluster using Elbow Method
bic=[]
aic =[]
k_range = range(2,10)
for i in k_range:
    gmm_temp = GaussianMixture(n_components=i, n_init=10)
    gmm_temp.fit(X_train)
    bic.append(gmm_temp.bic(X_train))
    aic.append(gmm_temp.aic(X_train))

# save the data for future use
bic_filename = os.path.join(outdir, f"bic_scores2_10.npy" )    
np.save(bic_filename, bic)

aic_filename = os.path.join(outdir, f"aic_scores2_10.npy" )    
np.save(aic_filename, aic)

# %%
print(len(bic))
# Out:
# 8

# %%
bic_filename = os.path.join(outdir, f"bic_scores2_10.npy" )    
aic_filename = os.path.join(outdir, f"bic_scores2_10.npy" )    
x_range = np.arange(2,10)
bic=np.load(bic_filename)
aic =np.load(aic_filename)


fig1 = plt.figure(figsize = (5,4))
plt.plot(x_range, bic, marker='o', label = "BIC Curve")
plt.plot(x_range, aic, marker='x', label = "AIC Curve")
plt.xlabel("Number of Clusters ")
plt.ylabel("AIC/BIC Values")
# for i, value in enumerate(wcss):
#     ax.text(i+1.05, value-0.005, round(value,1), fontsize=12, fontweight='bold')
    
#fig1.suptitle("Elbow Method");
plt.legend()
plt.show()

# %%
bgm = BayesianGaussianMixture(n_components=10, n_init=10)
bgm.fit(X_train)
np.round(bgm.weights_, 2)
# Out:
# array([0.15, 0.02, 0.  , 0.17, 0.54, 0.  , 0.07, 0.02, 0.  , 0.01])

# %%
gmm = GaussianMixture(n_components=7, n_init=10)

# %%
gmm.fit(X_train)
# Out:
# GaussianMixture(n_components=7, n_init=10)

# %%
predictions = gmm.predict_proba(X_train)

# %%
labels = gmm.predict(X_train)

# %%
X_train['pred_prob'] = predictions
X_train['labels'] = labels

# %%
sns.pairplot(X_train, vars=["BMI","GenHlth"], hue="pred_prob" , kind = "scatter",palette = "husl")

# %%
size = 50 * predictions.max(1) ** 2  # square emphasizes differences
#plt.scatter(X_train["BMI"], X_train["GenHlth"], c=labels, cmap='viridis', s=size);
ax = plt.gca()
ax.scatter(X_train["BMI"], X_train["GenHlth"], c=labels, s=40, cmap='viridis', zorder=2)
w_factor = 0.2 / gmm.weights_.max()
for mean, covar, w, color in zip(gmm.means_, gmm.covariances_, gmm.weights_, color_iter):
    alpha =w * w_factor 
    draw_ellipse(mean, covar, w, color,ax)

# %%
gmm.converged_
# Out:
# True

# %%
X_train.columns
# Out:
# Index(['HighBP', 'HighChol', 'CholCheck', 'BMI', 'Smoker', 'Stroke',
#        'HeartDiseaseorAttack', 'PhysActivity', 'Fruits', 'Veggies',
#        'HvyAlcoholConsump', 'AnyHealthcare', 'NoDocbcCost', 'GenHlth',
#        'MentHlth', 'PhysHlth', 'DiffWalk', 'Sex', 'Age', 'Education',
#        'Income'],
#       dtype='object')

# %%
sns.boxplot(X_train, y='BMI',x='labels')
# Out:
# <Axes: xlabel='labels', ylabel='BMI'>

# %% [markdown]
# ## KMode Algorithm

# %%
pip install kmodes
# Out:
# Collecting kmodes
#   Downloading kmodes-0.12.2-py2.py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: numpy>=1.10.4 in c:\users\pande\appdata\roaming\python\python310\site-packages (from kmodes) (1.26.1)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\users\pande\appdata\roaming\python\python310\site-packages (from kmodes) (1.4.0)
# Requirement already satisfied: scipy>=0.13.3 in c:\users\pande\appdata\roaming\python\python310\site-packages (from kmodes) (1.12.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\pande\appdata\roaming\python\python310\site-packages (from kmodes) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\pande\appdata\roaming\python\python310\site-packages (from scikit-learn>=0.22.0->kmodes) (3.3.0)
# Downloading kmodes-0.12.2-py2.py3-none-any.whl (20 kB)
# Installing collected packages: kmodes
# Successfully installed kmodes-0.12.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %%
from kmodes.kmodes import KModes

# %% [markdown]
# ### Find optimal number of clusters

# %% [markdown]
# #### Scree Plot or Elbow Curve

# %%
cost = []

K = range(2,7)
for num_clusters in list(K):
    kmode = KModes(num_clusters, init="random",n_init=5,verbose=1)
    kmode.fit_predict(X_train)
    cost.append(kmode.cost_)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 53287, cost: 1470196.0
# Run 1, iteration: 2/100, moves: 27950, cost: 1466035.0
# Run 1, iteration: 3/100, moves: 1976, cost: 1466035.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 27780, cost: 1504916.0
# Run 2, iteration: 2/100, moves: 6408, cost: 1504916.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 54084, cost: 1457448.0
# Run 3, iteration: 2/100, moves: 19433, cost: 1457448.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 51099, cost: 1466884.0
# Run 4, iteration: 2/100, moves: 3957, cost: 1466884.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 32255, cost: 1499812.0
# Run 5, iteration: 2/100, moves: 22899, cost: 1467837.0
# Run 5, iteration: 3/100, moves: 30369, cost: 1462599.0
# Run 5, iteration: 4/100, moves: 8669, cost: 1462599.0
# Best run was number 3
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 47341, cost: 1426007.0
# Run 1, iteration: 2/100, moves: 12031, cost: 1426007.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 59870, cost: 1424505.0
# Run 2, iteration: 2/100, moves: 10127, cost: 1424505.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 62027, cost: 1447794.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 70117, cost: 1439093.0
# Run 4, iteration: 2/100, moves: 13979, cost: 1439093.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 58547, cost: 1450924.0
# Run 5, iteration: 2/100, moves: 17381, cost: 1450924.0
# Best run was number 2
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 47046, cost: 1393105.0
# Run 1, iteration: 2/100, moves: 2194, cost: 1393105.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 62187, cost: 1382038.0
# Run 2, iteration: 2/100, moves: 7141, cost: 1382038.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 70734, cost: 1391536.0
# Run 3, iteration: 2/100, moves: 11125, cost: 1391536.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 73741, cost: 1395112.0
# Run 4, iteration: 2/100, moves: 1167, cost: 1395112.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 43121, cost: 1382119.0
# Best run was number 2
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 55905, cost: 1378984.0
# Run 1, iteration: 2/100, moves: 21648, cost: 1378984.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 90900, cost: 1352730.0
# Run 2, iteration: 2/100, moves: 18611, cost: 1352730.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 65443, cost: 1336183.0
# Run 3, iteration: 2/100, moves: 6845, cost: 1336183.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 66144, cost: 1371892.0
# Run 4, iteration: 2/100, moves: 9680, cost: 1371892.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 73116, cost: 1379062.0
# Best run was number 3
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 55270, cost: 1347882.0
# Run 1, iteration: 2/100, moves: 5145, cost: 1347882.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 66749, cost: 1351447.0
# Run 2, iteration: 2/100, moves: 24876, cost: 1339125.0
# Run 2, iteration: 3/100, moves: 4010, cost: 1339125.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 42047, cost: 1370834.0
# Run 3, iteration: 2/100, moves: 14824, cost: 1369601.0
# Run 3, iteration: 3/100, moves: 387, cost: 1369601.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 77638, cost: 1348234.0
# Run 4, iteration: 2/100, moves: 9409, cost: 1348234.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 61472, cost: 1367076.0
# Run 5, iteration: 2/100, moves: 8520, cost: 1367076.0
# Best run was number 2
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 72480, cost: 1336035.0
# Run 1, iteration: 2/100, moves: 14741, cost: 1323418.0
# Run 1, iteration: 3/100, moves: 6944, cost: 1322402.0
# Run 1, iteration: 4/100, moves: 646, cost: 1322402.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 35078, cost: 1336431.0
# Run 2, iteration: 2/100, moves: 16680, cost: 1336431.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 76462, cost: 1327166.0
# Run 3, iteration: 2/100, moves: 1231, cost: 1327166.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 55771, cost: 1341438.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 83113, cost: 1286246.0
# Run 5, iteration: 2/100, moves: 24412, cost: 1286246.0
# Best run was number 5
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 69586, cost: 1317000.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 70002, cost: 1318266.0
# Run 2, iteration: 2/100, moves: 3430, cost: 1318266.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 67890, cost: 1324824.0
# Run 3, iteration: 2/100, moves: 20813, cost: 1322030.0
# Run 3, iteration: 3/100, moves: 5450, cost: 1320127.0
# Run 3, iteration: 4/100, moves: 1618, cost: 1320127.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 59417, cost: 1326025.0
# Run 4, iteration: 2/100, moves: 8819, cost: 1326025.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 60591, cost: 1317523.0
# Run 5, iteration: 2/100, moves: 33277, cost: 1317523.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 57370, cost: 1310134.0
# Run 1, iteration: 2/100, moves: 10196, cost: 1307696.0
# Run 1, iteration: 3/100, moves: 209, cost: 1307696.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 46591, cost: 1322707.0
# Run 2, iteration: 2/100, moves: 7049, cost: 1322707.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 69010, cost: 1290710.0
# Run 3, iteration: 2/100, moves: 9788, cost: 1290710.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 70743, cost: 1309633.0
# Run 4, iteration: 2/100, moves: 10020, cost: 1304129.0
# Run 4, iteration: 3/100, moves: 708, cost: 1304129.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 84613, cost: 1325329.0
# Run 5, iteration: 2/100, moves: 9131, cost: 1325329.0
# Best run was number 3

# %%
kmode_cost_filename = os.path.join(outdir, f"kmode_costs.npy" )    
np.save(kmode_cost_filename, cost)

# %%
kmode_cost_filename = os.path.join(outdir, f"kmode_costs.npy" )      
k_range = np.arange(2,7)
k_costs=np.load(kmode_cost_filename)

plt.plot(k_range, k_costs[:5], 'bx-')
plt.xlabel('No. of clusters')
plt.ylabel('Cost')
plt.title('Elbow Method For Optimal k')
plt.show()

# %% [markdown]
# #### Silhouette Coefficient

# %%
from sklearn.metrics import silhouette_samples, silhouette_score

silhouette_scores = []

K = range(2,7)
for num_clusters in list(K):
    kmode = KModes(num_clusters, init="random",n_init=5,verbose=1)
    kmode_fitted=kmode.fit(X_train)
    cluster_labels = kmode_fitted.labels_
    silhouette_scores.append(silhouette_score(X_train, cluster_labels))
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 30399, cost: 1557742.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 56467, cost: 1464983.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 54677, cost: 1465630.0
# Run 3, iteration: 2/100, moves: 10320, cost: 1465630.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 28645, cost: 1554347.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 23529, cost: 1500374.0
# Best run was number 2
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 52849, cost: 1423099.0
# Run 1, iteration: 2/100, moves: 7829, cost: 1423099.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 39980, cost: 1425410.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 31178, cost: 1471574.0
# Run 3, iteration: 2/100, moves: 10825, cost: 1471574.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 37687, cost: 1447423.0
# Run 4, iteration: 2/100, moves: 620, cost: 1447423.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 57689, cost: 1418420.0
# Run 5, iteration: 2/100, moves: 7301, cost: 1418420.0
# Best run was number 5
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 52765, cost: 1393782.0
# Run 1, iteration: 2/100, moves: 25729, cost: 1393782.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 59083, cost: 1377880.0
# Run 2, iteration: 2/100, moves: 4523, cost: 1377880.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 68171, cost: 1404410.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 39824, cost: 1402627.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 70259, cost: 1408518.0
# Run 5, iteration: 2/100, moves: 22942, cost: 1401265.0
# Run 5, iteration: 3/100, moves: 6367, cost: 1401265.0
# Best run was number 2
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 49388, cost: 1371777.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 64965, cost: 1367740.0
# Run 2, iteration: 2/100, moves: 2490, cost: 1367740.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 57567, cost: 1362358.0
# Run 3, iteration: 2/100, moves: 10262, cost: 1358009.0
# Run 3, iteration: 3/100, moves: 1509, cost: 1358009.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 71775, cost: 1376642.0
# Run 4, iteration: 2/100, moves: 11788, cost: 1376642.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 71357, cost: 1361337.0
# Run 5, iteration: 2/100, moves: 10835, cost: 1361337.0
# Best run was number 3
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 45175, cost: 1355405.0
# Run 1, iteration: 2/100, moves: 897, cost: 1355405.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 65043, cost: 1357695.0
# Run 2, iteration: 2/100, moves: 9969, cost: 1357695.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 78611, cost: 1321052.0
# Run 3, iteration: 2/100, moves: 12218, cost: 1316993.0
# Run 3, iteration: 3/100, moves: 3024, cost: 1316993.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 73404, cost: 1338541.0
# Run 4, iteration: 2/100, moves: 25172, cost: 1332307.0
# Run 4, iteration: 3/100, moves: 1774, cost: 1332307.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 81168, cost: 1340452.0
# Run 5, iteration: 2/100, moves: 14926, cost: 1340452.0
# Best run was number 3

# %%
kmode_silhoutte_filename = os.path.join(outdir, f"kmode_silhouette.npy" )    
np.save(kmode_silhoutte_filename, silhouette_scores)

# %%
len(silhouette_scores)
# Out:
# 5

# %%
kmode_sil_filename = os.path.join(outdir, f"kmode_silhouette.npy" )      
k_range = np.arange(3,7)
k_sil=np.load(kmode_sil_filename)

plt.plot(k_range, k_sil[1:5], 'bx-')
plt.xlabel('No. of clusters')
plt.ylabel('Silhouette Scores')
#plt.title('Elbow Method For Optimal k')
plt.show()

# %% [markdown]
# ### Train KMode for clusters

# %%
kmode = KModes(n_clusters=5, init = "random", n_init = 5, verbose=1)
clusters = kmode.fit_predict(X_train)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 55153, cost: 1379465.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 53428, cost: 1372528.0
# Run 2, iteration: 2/100, moves: 3644, cost: 1372528.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 70984, cost: 1364904.0
# Run 3, iteration: 2/100, moves: 11352, cost: 1364904.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 51773, cost: 1369083.0
# Run 4, iteration: 2/100, moves: 2272, cost: 1369083.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 67234, cost: 1344648.0
# Run 5, iteration: 2/100, moves: 2071, cost: 1344648.0
# Best run was number 5

# %%
clusters
# Out:
# array([0, 1, 2, ..., 0, 1, 1], dtype=uint16)

# %%
cluster_centers_indices = kmode.cluster_centroids_ 
n_clusters = 5

# %%
from itertools import cycle
colors = cycle('bgrcmykbgrcmykbgrcmykbgrcmyk')

for k, col in zip(range(n_clusters), colors):
    class_members = clusters 
    cluster_center = cluster_centers_indices[k]
    plt.plot(X_train.iloc[class_members, 0], X_train.iloc[class_members, 1], col + '.')
    plt.plot(cluster_center[0], cluster_center[1], 'o', markerfacecolor=col,
             markeredgecolor='k', markersize=14)
    for x in X_train.iloc[class_members]:
        plt.plot([cluster_center[0], x[0]], [cluster_center[1], x[1]], col)

# %%
X_train['kmode_labels'] = clusters

# %%
sns.pairplot(X_train, vars=["BMI","GenHlth"], hue="kmode_labels" , kind = "scatter")

# %%
sns.pairplot(X_train, vars=["PhysHlth","GenHlth"], hue="kmode_labels")
