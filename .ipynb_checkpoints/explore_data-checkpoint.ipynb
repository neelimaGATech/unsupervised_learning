# %% [markdown]
# # Unsurpervised Learning Algorithm :

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
from matplotlib.patches import PathPatch as Patch
import numpy as np
import pandas as pd
import time
import seaborn as sns
from scipy import stats
sns.set()

# %%
diabetes_df = pd.read_csv('data/diabetes_012_health_indicators.csv')

# %%
diabetes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253680 entries, 0 to 253679
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Diabetes_012          253680 non-null  float64
#  1   HighBP                253680 non-null  float64
#  2   HighChol              253680 non-null  float64
#  3   CholCheck             253680 non-null  float64
#  4   BMI                   253680 non-null  float64
#  5   Smoker                253680 non-null  float64
#  6   Stroke                253680 non-null  float64
#  7   HeartDiseaseorAttack  253680 non-null  float64
#  8   PhysActivity          253680 non-null  float64
#  9   Fruits                253680 non-null  float64
#  10  Veggies               253680 non-null  float64
#  11  HvyAlcoholConsump     253680 non-null  float64
#  12  AnyHealthcare         253680 non-null  float64
#  13  NoDocbcCost           253680 non-null  float64
#  14  GenHlth               253680 non-null  float64
#  15  MentHlth              253680 non-null  float64
#  16  PhysHlth              253680 non-null  float64
#  17  DiffWalk              253680 non-null  float64
#  18  Sex                   253680 non-null  float64
#  19  Age                   253680 non-null  float64
#  20  Education             253680 non-null  float64
#  21  Income                253680 non-null  float64
# dtypes: float64(22)
# memory usage: 42.6 MB

# %%
diabetes_df.isnull().sum()
# Out:
# Diabetes_012            0
# HighBP                  0
# HighChol                0
# CholCheck               0
# BMI                     0
# Smoker                  0
# Stroke                  0
# HeartDiseaseorAttack    0
# PhysActivity            0
# Fruits                  0
# Veggies                 0
# HvyAlcoholConsump       0
# AnyHealthcare           0
# NoDocbcCost             0
# GenHlth                 0
# MentHlth                0
# PhysHlth                0
# DiffWalk                0
# Sex                     0
# Age                     0
# Education               0
# Income                  0
# dtype: int64

# %%
diabetes_df.duplicated().sum()
# Out:
# 23899

# %%
#Remove duplicated rows 
diabetes_df.drop_duplicates(inplace = True)

# %%
diabetes_df['Diabetes_012'].value_counts()
# Out:
# 0.0    190055
# 2.0     35097
# 1.0      4629
# Name: Diabetes_012, dtype: int64

# %%
diabetes_df.describe().T.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_a38bf_row0_col0, #T_a38bf_row0_col3, #T_a38bf_row0_col4, #T_a38bf_row0_col5, #T_a38bf_row0_col6, #T_a38bf_row1_col0, #T_a38bf_row1_col3, #T_a38bf_row1_col4, #T_a38bf_row1_col5, #T_a38bf_row1_col7, #T_a38bf_row2_col0, #T_a38bf_row2_col3, #T_a38bf_row2_col4, #T_a38bf_row2_col5, #T_a38bf_row2_col7, #T_a38bf_row3_col0, #T_a38bf_row3_col2, #T_a38bf_row3_col3, #T_a38bf_row3_col7, #T_a38bf_row4_col0, #T_a38bf_row5_col0, #T_a38bf_row5_col3, #T_a38bf_row5_col4, #T_a38bf_row5_col5, #T_a38bf_row5_col7, #T_a38bf_row6_col0, #T_a38bf_row6_col1, #T_a38bf_row6_col2, #T_a38bf_row6_col3, #T_a38bf_row6_col4, #T_a38bf_row6_col5, #T_a38bf_row6_col6, #T_a38bf_row6_col7, #T_a38bf_row7_col0, #T_a38bf_row7_col1, #T_a38bf_row7_col3, #T_a38bf_row7_col4, #T_a38bf_row7_col5, #T_a38bf_row7_col6, #T_a38bf_row7_col7, #T_a38bf_row8_col0, #T_a38bf_row8_col3, #T_a38bf_row8_col4, #T_a38bf_row8_col7, #T_a38bf_row9_col0, #T_a38bf_row9_col3, #T_a38bf_row9_col4, #T_a38bf_row9_col7, #T_a38bf_row10_col0, #T_a38bf_row10_col3, #T_a38bf_row10_col7, #T_a38bf_row11_col0, #T_a38bf_row11_col1, #T_a38bf_row11_col3, #T_a38bf_row11_col4, #T_a38bf_row11_col5, #T_a38bf_row11_col6, #T_a38bf_row11_col7, #T_a38bf_row12_col0, #T_a38bf_row12_col2, #T_a38bf_row12_col3, #T_a38bf_row12_col7, #T_a38bf_row13_col0, #T_a38bf_row13_col1, #T_a38bf_row13_col3, #T_a38bf_row13_col4, #T_a38bf_row13_col5, #T_a38bf_row13_col6, #T_a38bf_row13_col7, #T_a38bf_row14_col0, #T_a38bf_row15_col0, #T_a38bf_row15_col3, #T_a38bf_row15_col4, #T_a38bf_row15_col5, #T_a38bf_row16_col0, #T_a38bf_row16_col3, #T_a38bf_row16_col4, #T_a38bf_row16_col5, #T_a38bf_row17_col0, #T_a38bf_row17_col3, #T_a38bf_row17_col4, #T_a38bf_row17_col5, #T_a38bf_row17_col6, #T_a38bf_row17_col7, #T_a38bf_row18_col0, #T_a38bf_row18_col3, #T_a38bf_row18_col4, #T_a38bf_row18_col5, #T_a38bf_row18_col7, #T_a38bf_row19_col0, #T_a38bf_row20_col0, #T_a38bf_row21_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_a38bf_row0_col1, #T_a38bf_row0_col7, #T_a38bf_row13_col2 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_a38bf_row0_col2 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_a38bf_row1_col1, #T_a38bf_row2_col1, #T_a38bf_row5_col1, #T_a38bf_row7_col2, #T_a38bf_row18_col1 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_a38bf_row1_col2, #T_a38bf_row1_col6, #T_a38bf_row2_col2, #T_a38bf_row2_col6, #T_a38bf_row3_col1, #T_a38bf_row3_col6, #T_a38bf_row5_col2, #T_a38bf_row5_col6, #T_a38bf_row8_col6, #T_a38bf_row9_col2, #T_a38bf_row9_col6, #T_a38bf_row10_col6, #T_a38bf_row12_col1, #T_a38bf_row12_col6, #T_a38bf_row18_col2, #T_a38bf_row18_col6 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_a38bf_row3_col4, #T_a38bf_row10_col4, #T_a38bf_row12_col4, #T_a38bf_row14_col7 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_a38bf_row3_col5, #T_a38bf_row8_col5, #T_a38bf_row9_col5, #T_a38bf_row10_col5, #T_a38bf_row12_col5 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_a38bf_row4_col1, #T_a38bf_row4_col3, #T_a38bf_row4_col4, #T_a38bf_row4_col5, #T_a38bf_row4_col6, #T_a38bf_row4_col7, #T_a38bf_row16_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_a38bf_row4_col2 {
#   background-color: #cc191e;
#   color: #f1f1f1;
# }
# #T_a38bf_row8_col1, #T_a38bf_row10_col1 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_a38bf_row8_col2 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_a38bf_row9_col1, #T_a38bf_row10_col2, #T_a38bf_row17_col2 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_a38bf_row11_col2, #T_a38bf_row17_col1 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_a38bf_row14_col1 {
#   background-color: #fee7db;
#   color: #000000;
# }
# #T_a38bf_row14_col2 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_a38bf_row14_col3, #T_a38bf_row14_col4, #T_a38bf_row19_col3, #T_a38bf_row20_col3, #T_a38bf_row21_col3 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_a38bf_row14_col5 {
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_a38bf_row14_col6 {
#   background-color: #fee5d9;
#   color: #000000;
# }
# #T_a38bf_row15_col1 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# #T_a38bf_row15_col2 {
#   background-color: #ac1117;
#   color: #f1f1f1;
# }
# #T_a38bf_row15_col6 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_a38bf_row15_col7, #T_a38bf_row16_col7 {
#   background-color: #fcab8f;
#   color: #000000;
# }
# #T_a38bf_row16_col1 {
#   background-color: #fdd5c4;
#   color: #000000;
# }
# #T_a38bf_row16_col6 {
#   background-color: #fee0d2;
#   color: #000000;
# }
# #T_a38bf_row19_col1 {
#   background-color: #fcb296;
#   color: #000000;
# }
# #T_a38bf_row19_col2 {
#   background-color: #fca285;
#   color: #000000;
# }
# #T_a38bf_row19_col4, #T_a38bf_row21_col6 {
#   background-color: #fcbba1;
#   color: #000000;
# }
# #T_a38bf_row19_col5 {
#   background-color: #fcad90;
#   color: #000000;
# }
# #T_a38bf_row19_col6 {
#   background-color: #fca689;
#   color: #000000;
# }
# #T_a38bf_row19_col7 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_a38bf_row20_col1 {
#   background-color: #fdd2bf;
#   color: #000000;
# }
# #T_a38bf_row20_col2 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_a38bf_row20_col4 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_a38bf_row20_col5 {
#   background-color: #fdcebb;
#   color: #000000;
# }
# #T_a38bf_row20_col6 {
#   background-color: #fdcdb9;
#   color: #000000;
# }
# #T_a38bf_row20_col7 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_a38bf_row21_col1 {
#   background-color: #fdc9b3;
#   color: #000000;
# }
# #T_a38bf_row21_col2 {
#   background-color: #fdc6b0;
#   color: #000000;
# }
# #T_a38bf_row21_col4 {
#   background-color: #fdc7b2;
#   color: #000000;
# }
# #T_a38bf_row21_col5 {
#   background-color: #fcc4ad;
#   color: #000000;
# }
# #T_a38bf_row21_col7 {
#   background-color: #fee9df;
#   color: #000000;
# }
# </style>
# <table id="T_a38bf_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >mean</th>
#       <th class="col_heading level0 col2" >std</th>
#       <th class="col_heading level0 col3" >min</th>
#       <th class="col_heading level0 col4" >25%</th>
#       <th class="col_heading level0 col5" >50%</th>
#       <th class="col_heading level0 col6" >75%</th>
#       <th class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a38bf_level0_row0" class="row_heading level0 row0" >Diabetes_012</th>
#       <td id="T_a38bf_row0_col0" class="data row0 col0" >229781.000000</td>
#       <td id="T_a38bf_row0_col1" class="data row0 col1" >0.325627</td>
#       <td id="T_a38bf_row0_col2" class="data row0 col2" >0.724623</td>
#       <td id="T_a38bf_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_a38bf_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_a38bf_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_a38bf_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_a38bf_row0_col7" class="data row0 col7" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a38bf_level0_row1" class="row_heading level0 row1" >HighBP</th>
#       <td id="T_a38bf_row1_col0" class="data row1 col0" >229781.000000</td>
#       <td id="T_a38bf_row1_col1" class="data row1 col1" >0.454441</td>
#       <td id="T_a38bf_row1_col2" class="data row1 col2" >0.497921</td>
#       <td id="T_a38bf_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_a38bf_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_a38bf_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_a38bf_row1_col6" class="data row1 col6" >1.000000</td>
#       <td id="T_a38bf_row1_col7" class="data row1 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a38bf_level0_row2" class="row_heading level0 row2" >HighChol</th>
#       <td id="T_a38bf_row2_col0" class="data row2 col0" >229781.000000</td>
#       <td id="T_a38bf_row2_col1" class="data row2 col1" >0.441760</td>
#       <td id="T_a38bf_row2_col2" class="data row2 col2" >0.496598</td>
#       <td id="T_a38bf_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_a38bf_row2_col4" cla

# %%
for column in diabetes_df.columns:
    print(f"{column}:")
    print(f"{diabetes_df[column].unique()}")
# Out:
# Diabetes_012:
# [0. 2. 1.]
# HighBP:
# [1. 0.]
# HighChol:
# [1. 0.]
# CholCheck:
# [1. 0.]
# BMI:
# [40. 25. 28. 27. 24. 30. 34. 26. 33. 21. 23. 22. 38. 32. 37. 31. 29. 20.
#  35. 45. 39. 19. 47. 18. 36. 43. 55. 49. 42. 17. 16. 41. 44. 50. 59. 48.
#  52. 46. 54. 57. 53. 14. 15. 51. 58. 63. 61. 56. 74. 62. 64. 66. 73. 85.
#  60. 67. 65. 70. 82. 79. 92. 68. 72. 88. 96. 13. 81. 71. 75. 12. 77. 69.
#  76. 87. 89. 84. 95. 98. 91. 86. 83. 80. 90. 78.]
# Smoker:
# [1. 0.]
# Stroke:
# [0. 1.]
# HeartDiseaseorAttack:
# [0. 1.]
# PhysActivity:
# [0. 1.]
# Fruits:
# [0. 1.]
# Veggies:
# [1. 0.]
# HvyAlcoholConsump:
# [0. 1.]
# AnyHealthcare:
# [1. 0.]
# NoDocbcCost:
# [0. 1.]
# GenHlth:
# [5. 3. 2. 4. 1.]
# MentHlth:
# [18.  0. 30.  3.  5. 15. 10.  6. 20.  2. 25.  1.  4.  7.  8. 21. 14. 26.
#  29. 16. 28. 11. 12. 24. 17. 13. 27. 19. 22.  9. 23.]
# PhysHlth:
# [15.  0. 30.  2. 14. 28.  7. 20.  3. 10.  1.  5. 17.  4. 19.  6. 12. 25.
#  27. 21. 22.  8. 29. 24.  9. 16. 18. 23. 13. 26. 11.]
# DiffWalk:
# [1. 0.]
# Sex:
# [0. 1.]
# Age:
# [ 9.  7. 11. 10.  8. 13.  4.  6.  2. 12.  5.  1.  3.]
# Education:
# [4. 6. 3. 5. 2. 1.]
# Income:
# [3. 1. 8. 6. 4. 7. 2. 5.]

# %%
figure = plt.figure(figsize = (22,8))
count =0
for column in diabetes_df.columns:
    feature_name = column
    print(column)
    plt.subplot(5, 6, count+1)
    #if diabetes_df[feature_name].dtype == 'int': 
     #   sns.distplot(diabetes_df[feature_name], fit=stats.norm, color = 'red')        
    #else: 
    #sns.distplot(diabetes_df[feature_name], fit=stats.norm)  
    sns.barplot( x=diabetes_df[feature_name], y=diabetes_df['Diabetes_012'])
    count += 1
figure.tight_layout(h_pad=1.0, w_pad=0.5)
plt.suptitle('Bar charts', y=1.02)
plt.show()
# Out:
# Diabetes_012
# HighBP
# HighChol
# CholCheck
# BMI
# Smoker
# Stroke
# HeartDiseaseorAttack
# PhysActivity
# Fruits
# Veggies
# HvyAlcoholConsump
# AnyHealthcare
# NoDocbcCost
# GenHlth
# MentHlth
# PhysHlth
# DiffWalk
# Sex
# Age
# Education
# Income

# %%
fig3 = plt.figure(figsize = (15,8))

ax1 = fig3.add_subplot(2,3,1)
sns.kdeplot(diabetes_df[diabetes_df["Diabetes_012"]==1]["BMI"], shade=True, color="blue", label="Pre Diabetic", ax=ax1)
sns.kdeplot(diabetes_df[diabetes_df["Diabetes_012"]==0]["BMI"], shade=True, color="green", label="No Diabetes", ax=ax1)
sns.kdeplot(diabetes_df[diabetes_df["Diabetes_012"]==2]["BMI"], shade=True, color="red", label="Diabetic", ax=ax1)
ax1.set_xlabel("BMI")
ax1.set_ylabel("Density")

ax2 = fig3.add_subplot(2,3,2)
sns.kdeplot(diabetes_df[diabetes_df["Diabetes_012"]==1]["MentHlth"], shade=True, color="blue", label="Pre Diabetic", ax=ax2)
sns.kdeplot(diabetes_df[diabetes_df["Diabetes_012"]==0]["MentHlth"], shade=True, color="green", label="No Diabetes", ax=ax2)
sns.kdeplot(diabetes_df[diabetes_df["Diabetes_012"]==2]["MentHlth"], shade=True, color="red", label="Diabetic", ax=ax2)
ax1.set_xlabel("Mental Health")
ax1.set_ylabel("Density")

ax3 = fig3.add_subplot(2,3,3)
sns.kdeplot(diabetes_df[diabetes_df["Diabetes_012"]==1]["PhysHlth"], shade=True, color="blue", label="Pre Diabetic", ax=ax3)
sns.kdeplot(diabetes_df[diabetes_df["Diabetes_012"]==0]["PhysHlth"], shade=True, color="green", label="No Diabetes", ax=ax3)
sns.kdeplot(diabetes_df[diabetes_df["Diabetes_012"]==2]["PhysHlth"], shade=True, color="red", label="Diabetic", ax=ax3)
ax1.set_xlabel("Physical Health")
ax1.set_ylabel("Density")

fig3.suptitle("Density Plots for Continous variables");
plt.legend()
plt.show()

# %%
fig4, ax = plt.subplots()

sns.barplot( x=diabetes_df['Age'], y=diabetes_df['Diabetes_012'])

#plt.close(2) # catplot creates an extra figure we don't need

ax.set_xlabel("Age")



fig4.suptitle("Diabetes status vs. Age");

# %%
fig5 = plt.figure(figsize = (15,5))

sns.barplot( x=diabetes_df['MentHlth'], y=diabetes_df['Diabetes_012'])

#plt.close(2) # catplot creates an extra figure we don't need

ax.set_xlabel("Mental Health")



fig5.suptitle("Diabetes status vs. Mental Health");

# %%
fig5 = plt.figure(figsize = (15,5))

sns.barplot( x=diabetes_df['PhysHlth'], y=diabetes_df['Diabetes_012'])

#plt.close(2) # catplot creates an extra figure we don't need

ax.set_xlabel("Physical Health")



fig5.suptitle("Diabetes status vs. Physical Health");
