# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
from matplotlib.patches import PathPatch as Patch
import numpy as np
import pandas as pd
import time
import os

from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split

# %%
outdir = './data/processed_data'

# %%
 # read data from the file and plot 
filename = os.path.join(outdir, f"cleanded_diabetes_data.csv" )    
diabetes_df = pd.read_csv(filename)

# %%
# drop Diabetes_012 column from dataset to get input matrix X
X = diabetes_df.drop('Diabetes_012', axis=1)
# Extract Diabetes_012 column to generate output vector y
y = diabetes_df['Diabetes_012']

# %%
X_train, X_test, y_train_true, y_test_true = train_test_split(X, y, test_size=0.2)

# %%
pca = PCA()
pca.fit(X_train)
# Out:
# PCA()

# %%
cumsum = np.cumsum(pca.explained_variance_ratio_)

# %%
PC_values = np.arange(pca.n_components_) + 1
#plt.plot(PC_values, pca.explained_variance_ratio_, 'ro-', linewidth=2)
plt.plot(cumsum, marker='o')
plt.title('Cumulative Explained Variance by Principal Components')
plt.xlabel('Principal Component')
plt.ylabel('Proportion of Variance Explained')
plt.show()

# %%
plt.bar(range(1,22), pca.explained_variance_ratio_,
        alpha=0.5,
        align='center')
plt.step(range(1,22), np.cumsum(pca.explained_variance_ratio_),
         where='mid',
         color='red')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal Components')
plt.show()

# %%
# Eigenvalues 
eigenvalues = pca.explained_variance_

plt.plot(eigenvalues, marker='o', color='blue')
plt.xlabel("Eigenvalue number")
plt.ylabel("Eigenvalue size")
plt.title("Scree Plot")
plt.savefig('scree plot.png')

# %% [markdown]
# ### Create Reduced Component Diabetes dataframe using 5 components

# %%
pca_optimized = PCA(n_components=5)
X_train_reduced = pca_optimized.fit_transform(X_train)

# %%
diabetes_df_reduced = pd.DataFrame(X_train_reduced)

# %%
diabetes_df_reduced.shape
# Out:
# (183824, 5)

# %% [markdown]
# #### Store reduced diabetes dataframe to file

# %%
outdir = './data/processed_data'
if not os.path.exists(outdir):
    os.mkdir(outdir)

output_filename = os.path.join(outdir,f"reduced_diabetes_data.csv" )
diabetes_df_reduced.to_csv(output_filename,index=False)

# %% [markdown]
# ## PCA for Car Insurance Claim Dataset

# %%
# read data from the file and plot 
filename = os.path.join(outdir, f"cleanded_insurance_data.csv" )    
insurance_df = pd.read_csv(filename)

# %%
insurance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58592 entries, 0 to 58591
# Data columns (total 43 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   policy_tenure                     58592 non-null  float64
#  1   age_of_car                        58592 non-null  float64
#  2   age_of_policyholder               58592 non-null  float64
#  3   area_cluster                      58592 non-null  int64
#  4   population_density                58592 non-null  int64
#  5   make                              58592 non-null  int64
#  6   segment                           58592 non-null  int64
#  7   model                             58592 non-null  int64
#  8   fuel_type                         58592 non-null  int64
#  9   max_torque                        58592 non-null  object
#  10  max_power                         58592 non-null  object
#  11  engine_type                       58592 non-null  int64
#  12  airbags                           58592 non-null  int64
#  13  rear_brakes_type                  58592 non-null  int64
#  14  displacement                      58592 non-null  int64
#  15  cylinder                          58592 non-null  int64
#  16  transmission_type                 58592 non-null  int64
#  17  gear_box                          58592 non-null  int64
#  18  steering_type                     58592 non-null  int64
#  19  turning_radius                    58592 non-null  float64
#  20  length                            58592 non-null  int64
#  21  width                             58592 non-null  int64
#  22  height                            58592 non-null  int64
#  23  gross_weight                      58592 non-null  int64
#  24  ncap_rating                       58592 non-null  int64
#  25  is_claim                          58592 non-null  int64
#  26  is_esc                            58592 non-null  float64
#  27  is_adjustable_steering            58592 non-null  float64
#  28  is_tpms                           58592 non-null  float64
#  29  is_parking_sensors                58592 non-null  float64
#  30  is_parking_camera                 58592 non-null  float64
#  31  is_front_fog_lights               58592 non-null  float64
#  32  is_rear_window_wiper              58592 non-null  float64
#  33  is_rear_window_washer             58592 non-null  float64
#  34  is_rear_window_defogger           58592 non-null  float64
#  35  is_brake_assist                   58592 non-null  float64
#  36  is_power_door_locks               58592 non-null  float64
#  37  is_central_locking                58592 non-null  float64
#  38  is_power_steering                 58592 non-null  float64
#  39  is_driver_seat_height_adjustable  58592 non-null  float64
#  40  is_day_night_rear_view_mirror     58592 non-null  float64
#  41  is_ecw                            58592 non-null  float64
#  42  is_speed_alert                    58592 non-null  float64
# dtypes: float64(21), int64(20), object(2)
# memory usage: 19.2+ MB

# %%
# drop Diabetes_012 column from dataset to get input matrix X
X_insurance = insurance_df.drop('is_claim', axis=1)
# Extract Diabetes_012 column to generate output vector y
y_insurance = insurance_df['is_claim']

# %%
X_insurance_train, X_insurance_test, y_insurance_train_true, y_insurance_test_true = train_test_split(X, y, test_size=0.2)
